# %% [markdown]
# # Homework 3: PicoCTF
#
# ### Luis Cagigal (00211793)

# %% [markdown]
# -----------
# ### Cookies

# %% [markdown]
# 1. Typed 'snickerdoodle' into the text field and submit it.
# 2. Open the developer tools, and check for Cookies in the Application tab.
# 3. There is a single cookie named 'name' with value 0. Change it's value to 1 and refresh the page.
# 4. The message has changed, which means there is a page associated with every cookie value. Keep adding 1 to the cookie value until the flag is shown (Value = 18).
#
# Flag: picoCTF{3v3ry1_l0v3s_c00k135_96cdadfd}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -------
#
# ### Scavenger Hunt
#
# 1. Open the developer tools and inspect the files for clues in the Sources tab.
# 2. Open the HTML file first, notice there is a commented line with the first section of the file: ('picoCTF{t').
# 3. Next, open the CSS file. Again, there is a commented line with the next part of the flag: ('h4ts_4_l0').
# 4. Open the last available file, the JavaScript one. There is a comment with a clue: 'How can I keep Google from indexing my website?'. This clue refers to a common hidden filename in web applications named 'robots.txt'. Enter that file name in the URL path. The next part of the flag is shown: ('t_0f_pl4c').
# 5. In the 'robots.txt' file, there is a clue for the next part of the flag: 'I think this is an apache server... can you Access the next flag?'. This clue refers to another hidden file common in Apache servers used for optimization, named '.htaccess'. Enter that file into the URL. The page shows the next part of the flag: ('3s_2_lO0k').
# 6. In the '.htaccess' file, there is the last clue: 'I love making websites on my Mac, I can Store a lot of information there.'. This clue refers to a hidden file named '.DBStore' in Mac devices. Enter the file in the URL again, where the last part of the flag is shown: ('_35844447}')
#
# Flag: picoCTF{th4ts_4_l0t_0f_pl4c3s_2_lO0k_35844447}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ------
#
# ### findme
#
# 1. Launch the instance and open the developer tools' Network tab.
# 2. Enter the known username ('test') and password ('test!') and look at the Network tab data.
# 3. There are two redirects shown (which are too fast to notice with the naked eye). Both of these redirects have a coded-like string 'id'.
# 4. Look at the first one by clicking on it, and searching for the Request URL. Take all of the 'id' string value from the URL: ('cGljb0NURntwcm94aWVzX2Fs')
# 5. Now, look at the second one and repeat the process: ('bF90aGVfd2F5X2RmNDRjOTRjfQ=='). Both of these seem to be encoded in Base64.
# 6. Concatenate both, and use an online Base64 decoder. Decode the message and get the flag.
#
# Flag: picoCTF{proxies_all_the_way_df44c94c}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# --------
#
# ### Inspect HTML
#
# 1. Open the developer tools and enter the Sources tab.
# 2. Look at the single HTML file, and scroll to find the comment with the flag.
#
# Flag: picoCTF{1n5p3t0r_0f_h7ml_1fd8425b}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ------
#
# ### It is my Birthday
#
# 1. First, read carefully the description. Here it mentions similar MD5 hashes, but have small differences.
# 2. Look up for these hashes on Google, specifically, look out for 'MD5 collision' until you find this website: https://www.mscs.dal.ca/~selinger/md5collision/.
# 3. Look for two files named 'hello.exe' and 'erase.exe' and download them.
# 4. Change their extensions to PDF and upload them to the application.
# 5. If the upload was succesful, then a PHP file will be shown into the page, with the flag between the lines.
#
# Flag: ('picoCTF{c0ngr4ts_u_r_1nv1t3d_5c8c5ce2}')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -----
#
# ### Local Authority
#
# 1. Open the developer tools and enter the Sources tab. There is a single file there.
# 2. Enter any username and password. You will fail to login, but now there will be a file named 'secure.js' in the Sources tab.
# 3. If you look at that file, you will notice that the successful login conditions are written in plaintext inside and 'if' statement.
# 4. Enter the shown username and password to receive the flag.
#
# Flag: ('picoCTF{j5_15_7r4n5p4r3n7_b0c2c9cb}')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -----
#
# ### login
#
# 1. Open the developer tools and inspect the files in the Source tab.
# 2. If you look at the JavaScript file, you will notice a suspicious validation with a seemingly encoded string: 'cGljb0NURns1M3J2M3JfNTNydjNyXzUzcnYzcl81M3J2M3JfNTNydjNyfQ'.
# 3. If you notice the 'btoa()' JavaScript function and search for it, you will find that it encodes messages in Base64 encoding.
# 4. Use a Base64 decoder for the suspicious string, and you will get the flag.
#
# Flag: ('picoCTF{53rv3r_53rv3r_53rv3r_53rv3r_53rv3r}')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -----
#
# ### logon
#
# 1. Enter 'admin' as username and a random password. You will see that there is no permission to see the flag.
# 2. Open the developer tools and navigate to the Cookies tab.
# 3. Look at the session cookies, and you will notice a cookie named 'admin' with a 'False' value assigned.
# 4. Change that value to 'True' and refresh the page.
#
# Flag: ('picoCTF{th3_c0nsp1r4cy_l1v3s_6edb3f5f}')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -----
#
# ### Search source
#
# 1. Open the developer tools and navigate into the Sources tab.
# 2. Look for possible messages in each file with 'Ctrl+F'. Specifically, look out for 'pico'.
# 3. Enter the 'styles.css' and repeat the process, you will find the flag in a comment.
#
# Flag: ('picoCTF{1nsp3ti0n_0f_w3bpag3s_8de925a7}')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ------
#
# ### where are the robots
#
# 1. You will notice a clue in the front page: 'Where are the robots?'. This refers to a hidden file in web pages named 'robots.txt' which specifies instructions for web crawlers.
# 2. Type into the URL, the file extension 'robots.txt'. You will notice another clue: 'Disallow: /8028f.html'. That seems like another file that can be explored.
# 3. Enter the file in the URL path to retreive the flag.
#
# Flag: ('picoCTF{ca1cu1at1ng_Mach1n3s_8028f}')

# %% [markdown]
# ![image.png](attachment:image.png)
